# %%
import pandas as pd
df=pd.read_excel('loan3(na).xlsx')

# %%
df.head()
# Out:
#    loan  Industry_type  Company_type  ...  Age  Education  Credit
# 0   1.0              1           1.0  ...    3          2       2
# 1   1.0              2           1.0  ...    4          3       2
# 2   1.0              1           1.0  ...    3          4       1
# 3   1.0              2           1.0  ...    3          4       2
# 4   1.0              1           1.0  ...    2          3       2
#
# [5 rows x 10 columns]

# %%
df1=df.dropna()
X=df1[['Industry_type','Company_type','Beginning_time','Bank_relationship','Capital_increase','Age','Education','Credit']]
y=df1['loan'] 
from sklearn.model_selection import train_test_split #區分訓練集與測試集
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %% [markdown]
# ## **一、分類器(Decision Tree and Random Forest)**

# %% [markdown]
# # **決策樹(Decision Tree)**

# %%
#以決策樹建立預測模型
from sklearn import tree
DT = tree.DecisionTreeClassifier()
DT= DT.fit(X, y)

# %%
#列出各特徵重要程度
print('特徵重要程度: ',DT.feature_importances_)
# Out:
# 特徵重要程度:  [0.0830161  0.0592137  0.06834404 0.02743702 0.08218917 0.1203674
#  0.10276747 0.45666511]

# %%
#評估決策樹訓練集預測結果的混淆矩陣/精準度、召回率、F1
DT_pred= DT.predict(X_train)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_train,DT_pred))
print("======================================================\n")
print(classification_report(y_train,DT_pred))
# Out:
# [[123   1]
#  [  4  35]]
# ======================================================
#
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.99      0.98       124
#          2.0       0.97      0.90      0.93        39
#
#     accuracy                           0.97       163
#    macro avg       0.97      0.94      0.96       163
# weighted avg       0.97      0.97      0.97       163

# %%
#評估決策樹測試集預測結果的混淆矩陣/精準度、召回率、F1
DT_pred= DT.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,DT_pred))
print("======================================================\n")
print(classification_report(y_test,DT_pred))
# Out:
# [[28  0]
#  [ 0 13]]
# ======================================================
#
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00        28
#          2.0       1.00      1.00      1.00        13
#
#     accuracy                           1.00        41
#    macro avg       1.00      1.00      1.00        41
# weighted avg       1.00      1.00      1.00        41

# %%
#繪製決策樹圖型(黑白)
tree.plot_tree(DT)
# Out:
# [Text(130.56772959183675, 208.38, 'X[7] <= 1.5\ngini = 0.38\nsamples = 204\nvalue = [152, 52]'),
#  Text(58.077551020408166, 190.26, 'X[0] <= 1.5\ngini = 0.289\nsamples = 40\nvalue = [7, 33]'),
#  Text(34.16326530612245, 172.14, 'X[5] <= 2.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(20.49795918367347, 154.01999999999998, 'X[3] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(13.66530612244898, 135.89999999999998, 'X[6] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(6.83265306122449, 117.77999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(20.49795918367347, 117.77999999999999, 'X[2] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(13.66530612244898, 99.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(27.33061224489796, 99.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(27.33061224489796, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(47.82857142857143, 154.01999999999998, 'X[4] <= 3.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(40.99591836734694, 135.89999999999998, 'X[6] <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(34.16326530612245, 117.77999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(47.82857142857143, 117.77999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(54.66122448979592, 135.89999999999998, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(81.99183673469388, 172.14, 'X[4] <= 3.5\ngini = 0.121\nsamples = 31\nvalue = [2, 29]'),
#  Text(75.15918367346939, 154.01999999999998, 'X[6] <= 2.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(68.3265306122449, 135.89999999999998, 'X[1] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(61.49387755102041, 117.77999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(75.15918367346939, 117.77999999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(81.99183673469388, 135.89999999999998, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(88.82448979591837, 154.01999999999998, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(203.05790816326532, 190.26, 'X[3] <= 1.5\ngini = 0.205\nsamples = 164\nvalue = [145, 19]'),
#  Text(129.8204081632653, 172.14, 'X[5] <= 1.5\ngini = 0.143\nsamples = 129\nvalue = [119, 10]'),
#  Text(122.98775510204082, 154.01999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text
5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(273.3061224489796, 45.29999999999998, 'X[6] <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(266.47346938775513, 27.17999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(280.1387755102041, 27.17999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(300.63673469387754, 45.29999999999998, 'X[5] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(293.8040816326531, 27.17999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(307.46938775510205, 27.17999999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(321.13469387755106, 117.77999999999999, 'X[6] <= 1.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(314.30204081632655, 99.66, 'X[5] <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(307.46938775510205, 81.53999999999999, 'X[2] <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(300.63673469387754, 63.41999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(314.30204081632655, 63.41999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(321.13469387755106, 81.53999999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(327.9673469387755, 99.66, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(289.9607142857143, 135.89999999999998, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]')]

# %%
#儲存圖形(可於左側載入區下載圖形)
import graphviz 
dot_data = tree.export_graphviz(DT) 
graph = graphviz.Source(dot_data) 
graph.render("loan")
# Out:
# 'loan.pdf'

# %%
#繪製決策樹圖形(彩色)
dot_data = tree.export_graphviz(DT,feature_names=['Industry_type','Company_type','Beginning_time','Bank_relationship','Capital_increase','Age','Education','Credit'],    
                      filled=True, rounded=True)  
graph = graphviz.Source(dot_data)  
graph 
graph.render("loan2")
# Out:
# 'loan2.pdf'

# %% [markdown]
# # 決策樹圖形
# 前述決策樹特徵多不易說明，改取較少特徵分析說明

# %%
df2=df.dropna()
X=df2[['Industry_type','Bank_relationship','Age']]
y=df2['loan'] 
from sklearn.model_selection import train_test_split #區分訓練集與測試集
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
#以決策樹建立預測模型
from sklearn import tree
DT = tree.DecisionTreeClassifier()
DT= DT.fit(X, y)

# %%
#評估決策樹測試集預測結果的混淆矩陣/精準度、召回率、F1
DT_pred= DT.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,DT_pred))
print("======================================================\n")
print(classification_report(y_test,DT_pred))
# Out:
# [[27  1]
#  [ 5  8]]
# ======================================================
#
#               precision    recall  f1-score   support
#
#          1.0       0.84      0.96      0.90        28
#          2.0       0.89      0.62      0.73        13
#
#     accuracy                           0.85        41
#    macro avg       0.87      0.79      0.81        41
# weighted avg       0.86      0.85      0.85        41

# %%
#繪製決策樹圖形(彩色)
import graphviz 
dot_data = tree.export_graphviz(DT, out_file=None, 
                      feature_names=['Industry_type','Bank_relationship','Age'],    
                      filled=True, rounded=True)  
graph = graphviz.Source(dot_data)  
graph 
graph.render("loan3")
# Out:
# 'loan3.pdf'

# %% [markdown]
# # **隨機森林(Random Forest)**

# %%
df1=df.dropna()
X=df1[['Industry_type','Company_type','Beginning_time','Bank_relationship','Capital_increase','Age','Education','Credit']]
y=df1['loan'] 
from sklearn.model_selection import train_test_split #區分訓練集與測試集
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
#使用隨機森林進行機器學習模型
from sklearn.ensemble import RandomForestClassifier

#n_estimator代表要最高使用多少棵樹
RF = RandomForestClassifier(n_estimators=50,oob_score=True,random_state=3)

#從訓練組資料中建立隨機森林模型
RF.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# RandomForestClassifier(n_estimators=50, oob_score=True, random_state=3)

# %%
#列出各特徵重要程度
print('特徵重要程度: ',RF.feature_importances_)
print('oob score: ',RF.oob_score_)
# Out:
# 特徵重要程度:  [0.08233906 0.05538    0.14564975 0.08355359 0.07999366 0.16157354
#  0.109406   0.2821044 ]
# oob score:  0.8404907975460123

# %%
#評估隨機森林訓練集預測結果的精準度、召回率、F1
RF_pred= RF.predict(X_train)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_train,RF_pred))
print("======================================================\n")
print(classification_report(y_train,RF_pred))
# Out:
# [[123   1]
#  [  4  35]]
# ======================================================
#
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.99      0.98       124
#          2.0       0.97      0.90      0.93        39
#
#     accuracy                           0.97       163
#    macro avg       0.97      0.94      0.96       163
# weighted avg       0.97      0.97      0.97       163

# %%
#評估隨機森林測試集預測結果的精準度、召回率、F1
RF_pred= RF.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,RF_pred))
print("======================================================\n")
print(classification_report(y_test,RF_pred))
# Out:
# [[27  1]
#  [ 5  8]]
# ======================================================
#
#               precision    recall  f1-score   support
#
#          1.0       0.84      0.96      0.90        28
#          2.0       0.89      0.62      0.73        13
#
#     accuracy                           0.85        41
#    macro avg       0.87      0.79      0.81        41
# weighted avg       0.86      0.85      0.85        41

# %%
# 將分析結果以視覺化圖形呈現(僅可取其中一棵樹繪圖)
from sklearn import tree #導入決策樹模組
import graphviz #導入可視化模組
dot_df = \
    tree.export_graphviz(
            RF.estimators_[30], 
            out_file = None,
            feature_names=['Industry_type','Company_type','Beginning_time','Bank_relationship','Capital_increase','Age','Education','Credit'],
            filled = True,
            impurity = False,
            rounded = True)

graph=graphviz.Source(dot_df) #將分析結果以graphviz圖檔呈現
graph
#graph.render("loan4") #下載唯讀圖檔

# %% [markdown]
# # **二、“量”的預測模式(迴歸)：Decision Tree and Random Forest**

# %% [markdown]
# # **決策樹(Decision Tree)**

# %%
import pandas as pd
df = pd.DataFrame({'Q1': [2, 3, 5, 3, 6, 2, 7, 8, 6, 4],
                   'Q2': [12, 15, 21, 16, 29, 11, 33, 40, 30, 18]})

# %%
X=df[['Q1']]
y=df[['Q2']]

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
dot_data = tree.export_graphviz(regressor,feature_names=['Q1'],    
                      filled=True, rounded=True)  
graph = graphviz.Source(dot_data)  
graph 
graph.render("test")
# Out:
# 'test.pdf'

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
# 使用X_test預測y，得到y_pred1 
y_pred1 = regressor.predict(X)
rmse = sqrt(mean_squared_error(y, y_pred1)) 
print("rmse: %.3f" % rmse)
# Out:
# rmse: 0.387

# %% [markdown]
# # **隨機森林(Random Forest)**

# %%
from sklearn.ensemble import RandomForestRegressor

# 建立RandomForestRegressor模型
RF2 = RandomForestRegressor(n_estimators=3, criterion = 'mse')
# 使用訓練資料訓練模型
RF2.fit(X, y)
# 使用訓練資料預測
predicted=RF2.predict(X)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:392: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
# 使用X_test預測y，得到y_pred1 
y_pred1 = RF2.predict(X)
rmse = sqrt(mean_squared_error(y, y_pred1)) 
print("rmse: %.3f" % rmse)
# Out:
# rmse: 1.053

# %% [markdown]
# # 練習
# 1.請以salary.xlsx檔案資料的工作年資、教育年資與性別等特徵建立決策樹與隨機森林預測模式，預測年所得高於50或低於50（萬元）。(分類器：類別預測),分析後請畫出決策樹，並說明模式之判定準則。
#
# 2.請以salary.xlsx檔案資料的工作年資、教育年資與性別等特徵建立決策樹與隨機森林預測模式，預測年所得。(迴歸器：量的預測)，分析後請畫出決策樹，並說明模式之判定準則。

# %% [markdown]
# # 作業：
# (1)請利用boston_house(type).xlsx檔案中的指標，以決策樹來預測boston house的房價高低(Price Type)，分析後請畫出決策樹，並說明決策樹之主要判定準則。
#
# (2)請利用boston_house(type).xlsx檔案中的指標，以決策樹來預測boston house的房價(Price)，分析後請畫出決策樹，並說明決策樹之主要判定準則。
#
# 註： 1.資料與預測指標說明如附檔。 2.Price Type:1表單位房價低於20，2表單位房價高於20。
